# %%
import pandas as pd
import numpy as np

# %%
L2017 = pd.read_csv('listings_2017.csv')
L2018 = pd.read_csv('listings_2018.csv')
L2019 = pd.read_csv('listings_2019.csv')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', None)

# %%
L2017['year']=2017
L2018['year']=2018
L2019['year']=2019

# %%
L2017.head()
# Out:
#          id                                                name    host_id  \
# 0  18645859  New One Bedroom Spot Amsterdam Close to the Centre  129556555
# 1  16219344                 Wonderful double room facing Canal3   65918622
# 2  19023941                                             San Bnb  124384271
# 3  18957103                Comfortable room in A'dam (Wifi, TV)   39678806
# 4   4983904                                        Private Room   25691713
#
#     host_name  neighbourhood_group neighbourhood   latitude  longitude  \
# 0     Brandon                  NaN  Bijlmer-Oost  52.317641   4.981056
# 1      Mendes                  NaN  Bijlmer-Oost  52.317953   4.980712
# 2        Suzy                  NaN  Bijlmer-Oost  52.323022   4.964045
# 3    Jennifer                  NaN  Bijlmer-Oost  52.316814   4.969389
# 4  Mahaprabhu                  NaN  Bijlmer-Oost  52.312968   4.979377
#
#       room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
pd.concat([L2017,L2018,L2019])
main_df = pd.concat([L2017,L2018,L2019])
main_df
# Out:
#              id                                                 name  \
# 0      18645859   New One Bedroom Spot Amsterdam Close to the Centre
# 1      16219344                  Wonderful double room facing Canal3
# 2      19023941                                              San Bnb
# 3      18957103                 Comfortable room in A'dam (Wifi, TV)
# 4       4983904                                         Private Room
# ...         ...                                                  ...
# 20332  36495072   Apartment Amsterdam next to city center (1 person)
# 20333  36497290             Penthouse in Watergraafsmeer (Amsterdam)
# 20334  36497781  Cozy room in Amsterdam with nice (Hidden by Airbnb)
# 20335  36498483          City apartment near centre, water and beach
# 20336  36500242                    Room in lovely central  apartment
#
#          host_id   host_name  neighbourhood_group             neighbourhood  \
# ...

# %%
main_df.loc[main_df['room_type']== 'Entire home/apt']
# Out:
#              id                                                name  \
# 19     16177182  PRIVATE Studio 2mins to Station, ZIGGO, ArenA Ajax
# 20     12850813                        Great Apartment for families
# 21     17446031  2-bedroom apartment, 15mins to Ams Centre by metro
# 22      7880299                    Spacious apartment next to metro
# 23     18438311              Spacious apartment 15 min from center!
# ...         ...                                                 ...
# 20330  36490242              Exquisite and elegant fashion bed room
# 20331  36493694    Bamboo forest quiet high quality room / can cook
# 20332  36495072  Apartment Amsterdam next to city center (1 person)
# 20333  36497290            Penthouse in Watergraafsmeer (Amsterdam)
# 20335  36498483         City apartment near centre, water and beach
#
#          host_id   host_name  neighbourhood_group             neighbourhood  \
# ...

# %%
mask2017= main_df['year'] == 2017
mask2018= main_df['year'] == 2018
mask2019= main_df['year'] == 2019

# %%
main_df.loc[main_df['room_type']== 'Entire home/apt']  
avail18= main_df.loc[mask2017, 'availability_365'].max()
avail18
# Out:
# 365

# %%
entire_home= main_df.loc[main_df['room_type']== 'Entire home/apt']  
entire_home
# Out:
#              id                                                name  \
# 19     16177182  PRIVATE Studio 2mins to Station, ZIGGO, ArenA Ajax
# 20     12850813                        Great Apartment for families
# 21     17446031  2-bedroom apartment, 15mins to Ams Centre by metro
# 22      7880299                    Spacious apartment next to metro
# 23     18438311              Spacious apartment 15 min from center!
# ...         ...                                                 ...
# 20330  36490242              Exquisite and elegant fashion bed room
# 20331  36493694    Bamboo forest quiet high quality room / can cook
# 20332  36495072  Apartment Amsterdam next to city center (1 person)
# 20333  36497290            Penthouse in Watergraafsmeer (Amsterdam)
# 20335  36498483         City apartment near centre, water and beach
#
#          host_id   host_name  neighbourhood_group             neighbourhood  \
# ...

# %%
by_year= entire_home.groupby(['year']).mean()
by_year
# Out:
#                 id       host_id  neighbourhood_group   latitude  longitude  \
# year
# 2017  1.066943e+07  3.383980e+07                  NaN  52.365332   4.889414
# 2018  1.367563e+07  4.264506e+07                  NaN  52.365275   4.888805
# 2019  1.710690e+07  5.217975e+07                  NaN  52.365399   4.889184
#
#            price  minimum_nights  number_of_reviews  reviews_per_month  \
# year
# 2017  153.524849        3.009342          12.938510           1.008968
# 2018  160.008840        3.211059          14.018131           0.800629
# 2019  170.538643        3.843510          15.233280           0.667338
#
#       calculated_host_listings_count  availability_365
# year
# 2017                        3.551114         73.116778
# 2018                        3.994257         49.597174
# 2019                        5.736500         43.725167

# %%
main_df.groupby(['room_type','year'])['id'].count()
# Out:
# room_type        year
# Entire home/apt  2017    13059
#                  2018    15498
#                  2019    16148
# Private room     2017     3712
#                  2018     3980
#                  2019     4118
# Shared room      2017       66
#                  2018       60
#                  2019       71
# Name: id, dtype: int64

# %%
import seaborn as sns

# %%
ax = sns.countplot(x="room_type", hue="year", data=main_df)

# %%
#just entire homes
ax = sns.countplot(x="room_type", hue="year", data=entire_home)

# %%
main_df.groupby(['room_type','year'])['host_id'].nunique()
# Out:
# room_type        year
# Entire home/apt  2017    11769
#                  2018    14087
#                  2019    14600
# Private room     2017     3021
#                  2018     3276
#                  2019     3368
# Shared room      2017       62
#                  2018       57
#                  2019       57
# Name: host_id, dtype: int64

# %%
entire_home.groupby(['year'])['host_id'].nunique().plot.bar()

# %%
entire_home.groupby(["year"])["availability_365"].mean().plot.bar()

# %%
main_df.loc[main_df['room_type']== 'Private Room']
avail17= main_df.loc[mask2017, 'availability_365'].mean()
avail17
# Out:
# 84.44212151808517

# %%
main_df.loc[main_df['room_type']== 'Private Room']
avail18= main_df.loc[mask2018, 'availability_365'].mean()
avail18
# Out:
# 58.91119868973283

# %%
main_df.loc[main_df['room_type']== 'Private Room']
avail19= main_df.loc[mask2019, 'availability_365'].mean()
avail19
# Out:
# 53.92196489157693

# %%
#MEAN
main_df.loc[main_df['room_type']== 'Entire home/apt']  
avail17= main_df.loc[mask2017, 'availability_365'].mean()
avail17
# Out:
# 84.44212151808517

# %%
#MEAN
main_df.loc[main_df['room_type']== 'Entire home/apt']  
avail18= main_df.loc[mask2018, 'availability_365'].mean()
avail18
# Out:
# 58.91119868973283

# %%
#MEAN
main_df.loc[main_df['room_type']== 'Entire home/apt']  
avail19= main_df.loc[mask2019, 'availability_365'].mean()
avail19
# Out:
# 53.92196489157693

# %%
main_df.id.value_counts()
# Out:
# 19075070    3
# 13966282    3
# 11613014    3
# 4266835     3
# 1690441     3
#            ..
# 237882      1
# 2955565     1
# 25450789    1
# 27167007    1
# 3670016     1
# Name: id, Length: 30401, dtype: int64

# %%
main_df.loc[main_df['id']== 19075070]
# Out:
#              id                                               name   host_id  \
# 15962  19075070    Bright apartment on 10 minutes from the center.  10232186
# 13460  19075070  Bright & cozy apartment nearby centre & park | 2P  10232186
# 11410  19075070  Bright & cozy apartment nearby centre & park | 2P  10232186
#
#            host_name  neighbourhood_group  neighbourhood   latitude  \
# 15962  Rob En Marjan                  NaN  Bos en Lommer  52.375939
# 13460  Rob En Marjan                  NaN  Bos en Lommer  52.375939
# 11410  Rob En Marjan                  NaN  Bos en Lommer  52.375940
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 15962   4.850966  Entire home/apt    106               2                  1
# 13460   4.850966  Entire home/apt    106               2                  8
# 11410   4.850970  Entire home/apt    119               4                 10
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# ...

# %%
main_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'year'],
#       dtype='object')

# %%
pwd
# Out:
# 'C:\\Users\\asus\\Desktop\\Galvanize\\Airbnb'

# %%
main_df.to_csv("Amsterdam_all_3.csv")

# %%
L2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16837 entries, 0 to 16836
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              16837 non-null  int64
#  1   name                            16786 non-null  object
#  2   host_id                         16837 non-null  int64
#  3   host_name                       16834 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   16837 non-null  object
#  6   latitude                        16837 non-null  float64
#  7   longitude                       16837 non-null  float64
#  8   room_type                       16837 non-null  object
#  9   price                           16837 non-null  int64
#  10  minimum_nights                  16837 non-null  int64
#  11  number_of_reviews               16837 non-null  int64
# ...

# %%
L2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16837 entries, 0 to 16836
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              16837 non-null  int64
#  1   name                            16786 non-null  object
#  2   host_id                         16837 non-null  int64
#  3   host_name                       16834 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   16837 non-null  object
#  6   latitude                        16837 non-null  float64
#  7   longitude                       16837 non-null  float64
#  8   room_type                       16837 non-null  object
#  9   price                           16837 non-null  int64
#  10  minimum_nights                  16837 non-null  int64
#  11  number_of_reviews               16837 non-null  int64
# ...

# %%
main_df.describe()
# Out:
#                  id       host_id  neighbourhood_group      latitude  \
# count  5.671200e+04  5.671200e+04                  0.0  56712.000000
# mean   1.425986e+07  4.560873e+07                  NaN     52.365171
# std    8.570355e+06  5.389642e+07                  NaN      0.016120
# min    2.818000e+03  3.159000e+03                  NaN     52.289270
# 25%    7.298354e+06  7.831481e+06                  NaN     52.355169
# 50%    1.401769e+07  2.256522e+07                  NaN     52.364615
# 75%    1.960350e+07  6.585999e+07                  NaN     52.375020
# max    3.650024e+07  2.744219e+08                  NaN     52.428639
#
#           longitude         price  minimum_nights  number_of_reviews  \
# count  56712.000000  56712.000000    56712.000000       56712.000000
# mean       4.889487    149.018726        3.208862          20.619446
# std        0.035796    124.184786       14.016522          41.734091
# ...

# %%
mask2017= main_df['year'] == 2017
mask2018= main_df['year'] == 2018
mask2019= main_df['year'] == 2019

# %%
#avail17= main_df.loc[mask2017, 'availability_365'].value_counts() 
#this starts the count from zero, which we dont want to do becasue 
#we can tell if its zero because it is booked or if the person lapsed in using air bnb
#the index [1] tells us to start from count 1

# %%
#avail17= main_df.loc[mask2017, 'availability_365'].value_counts()[1:]
avail17= main_df.loc[mask2017, 'availability_365'].value_counts()
avail17
# Out:
# 0      5495
# 183     351
# 1       282
# 2       241
# 3       221
#        ...
# 262       7
# 345       7
# 100       7
# 227       6
# 108       5
# Name: availability_365, Length: 366, dtype: int64

# %%
avail17.groupby(['room_type'])[['availability365']].value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-8a6b18cd1f52> in <module>
# ----> 1 avail17.groupby(['room_type'])[['availability365']].value_counts()
#
# AttributeError: 'numpy.float64' object has no attribute 'groupby'

# %%
avail18= main_df.loc[mask2018, 'availability_365'].value_counts()[1:]
avail18
# Out:
# 1      407
# 3      344
# 186    310
# 2      288
# 4      275
#       ...
# 234      6
# 304      5
# 345      5
# 315      4
# 219      4
# Name: availability_365, Length: 365, dtype: int64

# %%
avail19= main_df.loc[mask2019, 'availability_365'].value_counts()[1:]
avail19.sum()
# Out:
# 10517

# %%
avail17.mean()
# Out:
# 84.44212151808517

# %%
avail18.mean()
# Out:
# 58.91119868973283

# %%
avail19.mean()
# Out:
# 53.92196489157693

# %%
import seaborn as sns
sns.distplot(avail19, bins=np.arange(1,366), kde=False, norm_hist=True)

# %%
avail19.hist(bins=100)

# %%
avail18.hist(bins=100)

# %%
avail17.hist(bins=100)

# %%
avail17.describe
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-7388067958e1> in <module>
# ----> 1 avail17['availability365'].mean()
#
# IndexError: invalid index to scalar variable.

# %%
sns.set(rc={'figure.figsize': (16,3)})
sns.countplot(avail19)

# %%
main_df.room_type.value_counts()
# Out:
# Entire home/apt    44705
# Private room       11810
# Shared room          197
# Name: room_type, dtype: int64

# %%
L2018.room_type.value_counts()
# Out:
# Entire home/apt    15498
# Private room        3980
# Shared room           60
# Name: room_type, dtype: int64

# %%
L2019.room_type.value_counts()
# Out:
# Entire home/apt    16148
# Private room        4118
# Shared room           71
# Name: room_type, dtype: int64

# %%
L2018['availability_365']
# Out:
# 0        116
# 1         12
# 2         99
# 3        100
# 4          5
#         ...
# 19533     10
# 19534      4
# 19535     29
# 19536     25
# 19537     23
# Name: availability_365, Length: 19538, dtype: int64

# %%
L2018
# Out:
#              id                                               name    host_id  \
# 0          2818           Quiet Garden View Room & Super Fast WiFi       3159
# 1          3209                  Quiet apt near center, great view       3806
# 2         20168  100%Centre-Private Floor/Bathroom-Lockable Studio      59484
# 3         25428                Lovely apt in City Centre (Jordaan)      56142
# 4         25488                    **Lovely 3 bedrooms Apartment *     106225
# ...         ...                                                ...        ...
# 19533  26634799                  Beautiful 2-bedroom in the center   11494498
# 19534  26635150                         Cosy apartment in the East   74657871
# 19535  26635265               Amsterdams appartement met dakterras   20808819
# 19536  26636227             Luxury Design Apartment ♛  at the park    1362930
# 19537  26636246              Cousy & comfortable room in Amsterdam  200229360
#
# ...

# %%
L2017.neighbourhood.value_counts()
# Out:
# De Baarsjes - Oud-West                    2873
# Centrum-West                              2145
# De Pijp - Rivierenbuurt                   2028
# Centrum-Oost                              1509
# Westerpark                                1242
# Zuid                                      1214
# Oud-Oost                                  1002
# Bos en Lommer                              869
# Oostelijk Havengebied - Indische Buurt     862
# Oud-Noord                                  490
# Watergraafsmeer                            457
# IJburg - Zeeburgereiland                   355
# Slotervaart                                328
# Buitenveldert - Zuidas                     231
# Noord-West                                 227
# Noord-Oost                                 213
# Geuzenveld - Slotermeer                    178
# Osdorp                                     162
# De Aker - Nieuw Sloten                     117
# Bijlmer-Centrum                            114
# ...

# %%
L2018.neighbourhood.value_counts()
# Out:
# De Baarsjes - Oud-West                    3436
# De Pijp - Rivierenbuurt                   2436
# Centrum-West                              2256
# Centrum-Oost                              1664
# Westerpark                                1455
# Zuid                                      1432
# Oud-Oost                                  1238
# Bos en Lommer                             1109
# Oostelijk Havengebied - Indische Buurt     948
# Oud-Noord                                  560
# Watergraafsmeer                            550
# IJburg - Zeeburgereiland                   464
# Slotervaart                                364
# Noord-West                                 305
# Buitenveldert - Zuidas                     251
# Noord-Oost                                 250
# Geuzenveld - Slotermeer                    215
# Osdorp                                     146
# De Aker - Nieuw Sloten                     143
# Gaasperdam - Driemond                      111
# ...

# %%
L2019.neighbourhood.value_counts()
# Out:
# De Baarsjes - Oud-West                    3468
# De Pijp - Rivierenbuurt                   2503
# Centrum-West                              2317
# Centrum-Oost                              1778
# Westerpark                                1506
# Zuid                                      1425
# Oud-Oost                                  1349
# Bos en Lommer                             1162
# Oostelijk Havengebied - Indische Buurt     966
# Oud-Noord                                  613
# Watergraafsmeer                            579
# IJburg - Zeeburgereiland                   491
# Slotervaart                                397
# Noord-West                                 363
# Noord-Oost                                 279
# Buitenveldert - Zuidas                     263
# Geuzenveld - Slotermeer                    220
# De Aker - Nieuw Sloten                     150
# Gaasperdam - Driemond                      142
# Osdorp                                     141
# ...

# %%
L2018.info
# Out:
# <bound method DataFrame.info of              id                                               name    host_id  \
# 0          2818           Quiet Garden View Room & Super Fast WiFi       3159
# 1          3209                  Quiet apt near center, great view       3806
# 2         20168  100%Centre-Private Floor/Bathroom-Lockable Studio      59484
# 3         25428                Lovely apt in City Centre (Jordaan)      56142
# 4         25488                    **Lovely 3 bedrooms Apartment *     106225
# ...         ...                                                ...        ...
# 19533  26634799                  Beautiful 2-bedroom in the center   11494498
# 19534  26635150                         Cosy apartment in the East   74657871
# 19535  26635265               Amsterdams appartement met dakterras   20808819
# 19536  26636227             Luxury Design Apartment ♛  at the park    1362930
# 19537  26636246              Cousy & comfortable room in Amsterdam  200229360
#
# ...

# %%
L2018.describe()
# Out:
#                  id       host_id  neighbourhood_group      latitude  \
# count  1.953800e+04  1.953800e+04                  0.0  19538.000000
# mean   1.392090e+07  4.450952e+07                  NaN     52.365194
# std    7.545627e+06  4.973924e+07                  NaN      0.015931
# min    2.818000e+03  3.159000e+03                  NaN     52.289274
# 25%    7.465516e+06  7.821454e+06                  NaN     52.355089
# 50%    1.429018e+07  2.242915e+07                  NaN     52.364561
# 75%    2.014442e+07  6.684103e+07                  NaN     52.375022
# max    2.663625e+07  2.002294e+08                  NaN     52.428639
#
#           longitude         price  minimum_nights  number_of_reviews  \
# count  19538.000000  19538.000000    19538.000000       19538.000000
# mean       4.889172    147.312929        3.077388          20.138192
# std        0.035713    105.603787       10.986325          39.864035
# ...

# %%
L2019.describe()
# Out:
#                  id       host_id  neighbourhood_group      latitude  \
# count  2.033700e+04  2.033700e+04                  0.0  20337.000000
# mean   1.741807e+07  5.541995e+07                  NaN     52.365276
# std    1.008320e+07  6.664982e+07                  NaN      0.016333
# min    2.818000e+03  3.159000e+03                  NaN     52.289270
# 25%    9.115414e+06  8.672889e+06                  NaN     52.355150
# 50%    1.731242e+07  2.560243e+07                  NaN     52.364630
# 75%    2.502876e+07  7.610421e+07                  NaN     52.375210
# max    3.650024e+07  2.744219e+08                  NaN     52.424710
#
#           longitude         price  minimum_nights  number_of_reviews  \
# count  20337.000000  20337.000000    20337.000000       20337.000000
# mean       4.889750    158.213650        3.632935          23.250529
# std        0.035936    157.519629       20.047582          48.238895
# ...
